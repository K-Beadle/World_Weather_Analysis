# %%
# Import dependencies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Import citipy module
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
        
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 757

# %%
# Starting URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in groups of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        
        # Convert the data to ISO standard
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Weather" : city_current,
                          #"Date": city_date
                         })
        
# If an error is experience, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chokurdakh
# Processing Record 2 of Set 1 | monte alegre
# Processing Record 3 of Set 1 | pimentel
# Processing Record 4 of Set 1 | rincon
# Processing Record 5 of Set 1 | comodoro rivadavia
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | sola
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | xichang
# Processing Record 12 of Set 1 | cleethorpes
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | port blair
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | tahara
# Processing Record 17 of Set 1 | guadalupe y calvo
# Processing Record 18 of Set 1 | lopatino
# Processing Record 19 of Set 1 | catacocha
# Processing Record 20 of Set 1 | krasnovishersk
# Processing Record 21 of Set 1 | druskininkai
# Processing Record 22 of Set 1 | porteirinha
# Processing Record 23 of Set 1 | jiangyou
# Processing Record 24 of Set 1 | ilo
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | provideniya
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | bedele
# Processing Record 32 of Set 1 | pokhara
# Processing Record 33 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | severo-kurilsk
# Processing Record 37 of Set 1 | beringovskiy
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | ust-ilimsk
# Processing Record 45 of Set 1 | kurilsk
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | dogondoutchi
# Processing Record 48 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 1 | saldanha
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | kirensk
# Processing Record 5 of Set 2 | nokha
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | bethel
# Processing Record 9 of Set 2 | binzhou
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | faanui
# Processing Record 12 of Set 2 | vanimo
# Processing Record 13 of Set 2 | laguna
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | vila
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | cidreira
# Processing Record 18 of Set 2 | vila franca do campo
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | pontianak
# Processing Record 21 of Set 2 | punta arenas
# Processing Record 22 of Set 2 | constitucion
# Processing Record 23 of Set 2 | kavieng
# Processing Record 24 of Set 2 | goderich
# Processing Record 25 of Set 2 | lorengau
# Processing Record 26 of Set 2 | wattegama
# Processing Record 27 of Set 2 | portobelo
# Processing Record 28 of Set 2 | makakilo city
# Processing Record 29 of Set 2 | gibraleon
# Processing Record 30 of Set 2 | klaksvik
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | thompson
# Processing Record 33 of Set 2 | aldan
# Processing Record 34 of Set 2 | airai
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | nouakchott
# Processing Record 37 of Set 2 | burnie
# Processing Record 38 of Set 2 | jacareacanga
# Processing Record 39 of Set 2 | kamaishi
# Processing Record 40 of Set 2 | nhulunbuy
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | sitka
# Processing Record 43 of Set 2 | iqaluit
# Processing Record 44 of Set 2 | bireun
# Processing Record 45 of Set 2 | save
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | krasnoarmeysk
# Processing Record 49 of Set 2 | elk city
# Processing Record 50 of Set 2 | beaune
# Processing Record 1 of Set 3 | college
# Processing Record 2 of Set 3 | adelaide
# Processing Record 3 of Set 3 | cabedelo
# Processing Record 4 of Set 3 | ulkan
# Processing Record 5 of Set 3 | mubi
# Processing Record 6 of Set 3 | conde
# Processing Record 7 of Set 3 | vila velha
# Processing Record 8 of Set 3 | chastoozerye
# City not found. Skipping...
# Processing Record 9 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 3 | kaitangata
# Processing Record 12 of Set 3 | broken hill
# Processing Record 13 of Set 3 | talnakh
# Processing Record 14 of Set 3 | kavaratti
# Processing Record 15 of Set 3 | fortuna
# Processing Record 16 of Set 3 | upernavik
# Processing Record 17 of Set 3 | san patricio
# Processing Record 18 of Set 3 | sorbhog
# Processing Record 19 of Set 3 | urumqi
# Processing Record 20 of Set 3 | kozhevnikovo
# Processing Record 21 of Set 3 | kapit
# Processing Record 22 of Set 3 | rudnogorsk
# Processing Record 23 of Set 3 | cherskiy
# Processing Record 24 of Set 3 | bredasdorp
# Processing Record 25 of Set 3 | cabo san lucas
# Processing Record 26 of Set 3 | ostrovnoy
# Processing Record 27 of Set 3 | te anau
# Processing Record 28 of Set 3 | yellowknife
# Processing Record 29 of Set 3 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 30 of Set 3 | purpe
# Processing Record 31 of Set 3 | zhigansk
# Processing Record 32 of Set 3 | kathu
# Processing Record 33 of Set 3 | karibib
# Processing Record 34 of Set 3 | souillac
# Processing Record 35 of Set 3 | cukai
# Processing Record 36 of Set 3 | kawalu
# Processing Record 37 of Set 3 | cockburn town
# Processing Record 38 of Set 3 | soyo
# Processing Record 39 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 40 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 3 | tiarei
# Processing Record 42 of Set 3 | kodiak
# Processing Record 43 of Set 3 | kruisfontein
# Processing Record 44 of Set 3 | chitral
# Processing Record 45 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 3 | belmonte
# Processing Record 47 of Set 3 | talara
# Processing Record 48 of Set 3 | sao filipe
# Processing Record 49 of Set 3 | avarua
# Processing Record 50 of Set 3 | ternate
# Processing Record 1 of Set 4 | port hedland
# Processing Record 2 of Set 4 | merrill
# Processing Record 3 of Set 4 | havelock
# Processing Record 4 of Set 4 | ye
# City not found. Skipping...
# Processing Record 5 of Set 4 | waipawa
# Processing Record 6 of Set 4 | deputatskiy
# Processing Record 7 of Set 4 | riyadh
# Processing Record 8 of Set 4 | sibolga
# Processing Record 9 of Set 4 | novikovo
# Processing Record 10 of Set 4 | khandyga
# Processing Record 11 of Set 4 | dolores
# Processing Record 12 of Set 4 | ribeira grande
# Processing Record 13 of Set 4 | rio pardo
# Processing Record 14 of Set 4 | mossendjo
# Processing Record 15 of Set 4 | matara
# Processing Record 16 of Set 4 | dalbandin
# Processing Record 17 of Set 4 | puerto ayora
# Processing Record 18 of Set 4 | panzhihua
# Processing Record 19 of Set 4 | sao joao da barra
# Processing Record 20 of Set 4 | keti bandar
# Processing Record 21 of Set 4 | lipin bor
# Processing Record 22 of Set 4 | avera
# Processing Record 23 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 4 | luganville
# Processing Record 25 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 4 | marsa matruh
# Processing Record 27 of Set 4 | adre
# Processing Record 28 of Set 4 | broome
# Processing Record 29 of Set 4 | hambantota
# Processing Record 30 of Set 4 | moussoro
# Processing Record 31 of Set 4 | marivan
# Processing Record 32 of Set 4 | lazi
# Processing Record 33 of Set 4 | port-gentil
# Processing Record 34 of Set 4 | houma
# Processing Record 35 of Set 4 | oktyabrskiy
# Processing Record 36 of Set 4 | adrar
# Processing Record 37 of Set 4 | two rivers
# Processing Record 38 of Set 4 | robertson
# Processing Record 39 of Set 4 | pionerskiy
# Processing Record 40 of Set 4 | nara
# Processing Record 41 of Set 4 | leshukonskoye
# Processing Record 42 of Set 4 | talovaya
# Processing Record 43 of Set 4 | muroto
# Processing Record 44 of Set 4 | port elizabeth
# Processing Record 45 of Set 4 | itarema
# Processing Record 46 of Set 4 | dikson
# Processing Record 47 of Set 4 | kanye
# Processing Record 48 of Set 4 | amahai
# Processing Record 49 of Set 4 | hamada
# Processing Record 50 of Set 4 | nalut
# Processing Record 1 of Set 5 | tuatapere
# Processing Record 2 of Set 5 | fort nelson
# Processing Record 3 of Set 5 | eureka
# Processing Record 4 of Set 5 | guelengdeng
# City not found. Skipping...
# Processing Record 5 of Set 5 | kahului
# Processing Record 6 of Set 5 | ust-kuyga
# Processing Record 7 of Set 5 | diamantino
# Processing Record 8 of Set 5 | clyde river
# Processing Record 9 of Set 5 | isangel
# Processing Record 10 of Set 5 | ust-ishim
# Processing Record 11 of Set 5 | nieuw amsterdam
# Processing Record 12 of Set 5 | merauke
# Processing Record 13 of Set 5 | riviere-au-renard
# Processing Record 14 of Set 5 | castro
# Processing Record 15 of Set 5 | porkhov
# Processing Record 16 of Set 5 | acarau
# Processing Record 17 of Set 5 | mahebourg
# Processing Record 18 of Set 5 | mitsamiouli
# Processing Record 19 of Set 5 | ilave
# Processing Record 20 of Set 5 | buchanan
# Processing Record 21 of Set 5 | belyy yar
# Processing Record 22 of Set 5 | palmer
# Processing Record 23 of Set 5 | hasaki
# Processing Record 24 of Set 5 | camacha
# Processing Record 25 of Set 5 | nikolskoye
# Processing Record 26 of Set 5 | inongo
# Processing Record 27 of Set 5 | nishihara
# Processing Record 28 of Set 5 | namatanai
# Processing Record 29 of Set 5 | bengkulu
# Processing Record 30 of Set 5 | saint george
# Processing Record 31 of Set 5 | cairns
# Processing Record 32 of Set 5 | pevek
# Processing Record 33 of Set 5 | okitipupa
# Processing Record 34 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 35 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 36 of Set 5 | kota belud
# Processing Record 37 of Set 5 | pampa
# Processing Record 38 of Set 5 | konstantinovsk
# Processing Record 39 of Set 5 | zhanaozen
# Processing Record 40 of Set 5 | nizhnevartovsk
# Processing Record 41 of Set 5 | torbay
# Processing Record 42 of Set 5 | marzuq
# Processing Record 43 of Set 5 | aksu
# Processing Record 44 of Set 5 | andevoranto
# City not found. Skipping...
# Processing Record 45 of Set 5 | odienne
# Processing Record 46 of Set 5 | los llanos de aridane
# Processing Record 47 of Set 5 | nome
# Processing Record 48 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 5 | dunedin
# Processing Record 50 of Set 5 | karratha
# Processing Record 1 of Set 6 | springbok
# Processing Record 2 of Set 6 | rawalpindi
# Processing Record 3 of Set 6 | saskylakh
# Processing Record 4 of Set 6 | guerrero negro
# Processing Record 5 of Set 6 | normandin
# Processing Record 6 of Set 6 | zhangjiakou
# Processing Record 7 of Set 6 | geraldton
# Processing Record 8 of Set 6 | marystown
# Processing Record 9 of Set 6 | puerto el triunfo
# Processing Record 10 of Set 6 | rzhyshchiv
# Processing Record 11 of Set 6 | ouesso
# Processing Record 12 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 6 | touros
# Processing Record 14 of Set 6 | sorland
# Processing Record 15 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 6 | lavrentiya
# Processing Record 17 of Set 6 | calvinia
# Processing Record 18 of Set 6 | santiago
# Processing Record 19 of Set 6 | sinnamary
# Processing Record 20 of Set 6 | ixtapa
# Processing Record 21 of Set 6 | kargasok
# Processing Record 22 of Set 6 | sungairaya
# Processing Record 23 of Set 6 | lasa
# Processing Record 24 of Set 6 | honningsvag
# Processing Record 25 of Set 6 | ordzhonikidze
# Processing Record 26 of Set 6 | usinsk
# Processing Record 27 of Set 6 | saint-joseph
# Processing Record 28 of Set 6 | bend
# Processing Record 29 of Set 6 | lingao
# Processing Record 30 of Set 6 | srandakan
# Processing Record 31 of Set 6 | sept-iles
# Processing Record 32 of Set 6 | juegang
# Processing Record 33 of Set 6 | pabna
# Processing Record 34 of Set 6 | kayerkan
# Processing Record 35 of Set 6 | sobolevo
# Processing Record 36 of Set 6 | battle creek
# Processing Record 37 of Set 6 | santa cruz do capibaribe
# Processing Record 38 of Set 6 | umm kaddadah
# Processing Record 39 of Set 6 | san cristobal
# Processing Record 40 of Set 6 | tazovskiy
# Processing Record 41 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 6 | moba
# Processing Record 43 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 6 | ahipara
# Processing Record 45 of Set 6 | taltal
# Processing Record 46 of Set 6 | sambava
# Processing Record 47 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 6 | kananga
# Processing Record 49 of Set 6 | muisne
# Processing Record 50 of Set 6 | arlit
# Processing Record 1 of Set 7 | chuy
# Processing Record 2 of Set 7 | lata
# Processing Record 3 of Set 7 | barkhan
# Processing Record 4 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 5 of Set 7 | yarada
# Processing Record 6 of Set 7 | saint anthony
# Processing Record 7 of Set 7 | kirakira
# Processing Record 8 of Set 7 | marabba
# Processing Record 9 of Set 7 | lethem
# Processing Record 10 of Set 7 | husavik
# Processing Record 11 of Set 7 | hamilton
# Processing Record 12 of Set 7 | dauphin
# Processing Record 13 of Set 7 | vardo
# Processing Record 14 of Set 7 | juneau
# Processing Record 15 of Set 7 | lagoa
# Processing Record 16 of Set 7 | sao felix do xingu
# Processing Record 17 of Set 7 | santa catarina de tepehuanes
# Processing Record 18 of Set 7 | windhoek
# Processing Record 19 of Set 7 | longyearbyen
# Processing Record 20 of Set 7 | tabou
# Processing Record 21 of Set 7 | narsaq
# Processing Record 22 of Set 7 | gamba
# Processing Record 23 of Set 7 | nemuro
# Processing Record 24 of Set 7 | byron bay
# Processing Record 25 of Set 7 | codrington
# Processing Record 26 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 27 of Set 7 | kaduqli
# Processing Record 28 of Set 7 | pirassununga
# Processing Record 29 of Set 7 | barrie
# Processing Record 30 of Set 7 | aloleng
# Processing Record 31 of Set 7 | charcas
# Processing Record 32 of Set 7 | coquimbo
# Processing Record 33 of Set 7 | aklavik
# Processing Record 34 of Set 7 | ciechanow
# Processing Record 35 of Set 7 | pisco
# Processing Record 36 of Set 7 | san bartolome de tirajana
# Processing Record 37 of Set 7 | norman wells
# Processing Record 38 of Set 7 | shenavan
# Processing Record 39 of Set 7 | port moresby
# Processing Record 40 of Set 7 | poum
# Processing Record 41 of Set 7 | zaysan
# Processing Record 42 of Set 7 | bahia blanca
# Processing Record 43 of Set 7 | tura
# Processing Record 44 of Set 7 | esperance
# Processing Record 45 of Set 7 | chambas
# Processing Record 46 of Set 7 | vostok
# Processing Record 47 of Set 7 | ouadda
# Processing Record 48 of Set 7 | alanya
# Processing Record 49 of Set 7 | taoudenni
# Processing Record 50 of Set 7 | kuhdasht
# Processing Record 1 of Set 8 | glenwood springs
# Processing Record 2 of Set 8 | muros
# Processing Record 3 of Set 8 | visnes
# Processing Record 4 of Set 8 | ballina
# Processing Record 5 of Set 8 | binucayan
# Processing Record 6 of Set 8 | portland
# Processing Record 7 of Set 8 | oranjemund
# Processing Record 8 of Set 8 | suwalki
# Processing Record 9 of Set 8 | mukhen
# Processing Record 10 of Set 8 | antofagasta
# Processing Record 11 of Set 8 | patan
# Processing Record 12 of Set 8 | weligama
# Processing Record 13 of Set 8 | leh
# Processing Record 14 of Set 8 | chapais
# Processing Record 15 of Set 8 | butajira
# Processing Record 16 of Set 8 | russell
# Processing Record 17 of Set 8 | nuuk
# Processing Record 18 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 8 | samarai
# Processing Record 20 of Set 8 | margate
# Processing Record 21 of Set 8 | ritchie
# Processing Record 22 of Set 8 | rawson
# Processing Record 23 of Set 8 | horodnytsya
# Processing Record 24 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 8 | harper
# Processing Record 26 of Set 8 | omsukchan
# Processing Record 27 of Set 8 | bjornevatn
# Processing Record 28 of Set 8 | tommot
# Processing Record 29 of Set 8 | lima
# Processing Record 30 of Set 8 | jose de freitas
# Processing Record 31 of Set 8 | dongying
# Processing Record 32 of Set 8 | rongcheng
# Processing Record 33 of Set 8 | salcedo
# Processing Record 34 of Set 8 | ilulissat
# Processing Record 35 of Set 8 | pangnirtung
# Processing Record 36 of Set 8 | saint-pierre
# Processing Record 37 of Set 8 | jiazi
# Processing Record 38 of Set 8 | cabra
# Processing Record 39 of Set 8 | copiapo
# Processing Record 40 of Set 8 | slavutych
# Processing Record 41 of Set 8 | leningradskiy
# Processing Record 42 of Set 8 | nanortalik
# Processing Record 43 of Set 8 | mundargi
# Processing Record 44 of Set 8 | korla
# Processing Record 45 of Set 8 | katsuura
# Processing Record 46 of Set 8 | phalaborwa
# Processing Record 47 of Set 8 | brandon
# Processing Record 48 of Set 8 | port lincoln
# Processing Record 49 of Set 8 | kalanguy
# Processing Record 50 of Set 8 | kemijarvi
# Processing Record 1 of Set 9 | cayenne
# Processing Record 2 of Set 9 | the pas
# Processing Record 3 of Set 9 | tefe
# Processing Record 4 of Set 9 | rizhao
# Processing Record 5 of Set 9 | rovaniemi
# Processing Record 6 of Set 9 | bundaberg
# Processing Record 7 of Set 9 | shingu
# Processing Record 8 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 9 | wamba
# Processing Record 10 of Set 9 | pochutla
# Processing Record 11 of Set 9 | alakurtti
# Processing Record 12 of Set 9 | gornyy
# Processing Record 13 of Set 9 | mehamn
# Processing Record 14 of Set 9 | grootfontein
# Processing Record 15 of Set 9 | afyonkarahisar
# Processing Record 16 of Set 9 | healdsburg
# Processing Record 17 of Set 9 | arroyo
# Processing Record 18 of Set 9 | biak
# Processing Record 19 of Set 9 | baiyin
# Processing Record 20 of Set 9 | zhoucheng
# Processing Record 21 of Set 9 | bambous virieux
# Processing Record 22 of Set 9 | montepuez
# Processing Record 23 of Set 9 | pontes e lacerda
# Processing Record 24 of Set 9 | ndele
# Processing Record 25 of Set 9 | goya
# Processing Record 26 of Set 9 | illela
# Processing Record 27 of Set 9 | akdepe
# Processing Record 28 of Set 9 | dire
# Processing Record 29 of Set 9 | whitley bay
# Processing Record 30 of Set 9 | nesna
# Processing Record 31 of Set 9 | bud
# Processing Record 32 of Set 9 | matagami
# Processing Record 33 of Set 9 | rocha
# Processing Record 34 of Set 9 | mount gambier
# Processing Record 35 of Set 9 | molochnoye
# Processing Record 36 of Set 9 | beruwala
# Processing Record 37 of Set 9 | hay river
# Processing Record 38 of Set 9 | kempele
# Processing Record 39 of Set 9 | maniitsoq
# Processing Record 40 of Set 9 | bolivar
# Processing Record 41 of Set 9 | port hawkesbury
# Processing Record 42 of Set 9 | lompoc
# Processing Record 43 of Set 9 | chifeng
# Processing Record 44 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 45 of Set 9 | sisimiut
# Processing Record 46 of Set 9 | tortoli
# Processing Record 47 of Set 9 | honolulu
# Processing Record 48 of Set 9 | okara
# Processing Record 49 of Set 9 | eyl
# Processing Record 50 of Set 9 | mount isa
# Processing Record 1 of Set 10 | burica
# City not found. Skipping...
# Processing Record 2 of Set 10 | domoni
# Processing Record 3 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 10 | stamsund
# City not found. Skipping...
# Processing Record 5 of Set 10 | dingle
# Processing Record 6 of Set 10 | gat
# Processing Record 7 of Set 10 | srednekolymsk
# Processing Record 8 of Set 10 | moratuwa
# Processing Record 9 of Set 10 | kikwit
# Processing Record 10 of Set 10 | durango
# Processing Record 11 of Set 10 | masterton
# Processing Record 12 of Set 10 | boueni
# Processing Record 13 of Set 10 | masvingo
# Processing Record 14 of Set 10 | yefimovskiy
# City not found. Skipping...
# Processing Record 15 of Set 10 | chateau-thierry
# Processing Record 16 of Set 10 | kalianget
# Processing Record 17 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 10 | bosaso
# Processing Record 19 of Set 10 | imbituba
# Processing Record 20 of Set 10 | morlaix
# Processing Record 21 of Set 10 | faya
# Processing Record 22 of Set 10 | yankton
# Processing Record 23 of Set 10 | berdigestyakh
# Processing Record 24 of Set 10 | nyurba
# Processing Record 25 of Set 10 | paita
# Processing Record 26 of Set 10 | buraydah
# Processing Record 27 of Set 10 | yar-sale
# Processing Record 28 of Set 10 | veinticinco de mayo
# Processing Record 29 of Set 10 | erdenet
# Processing Record 30 of Set 10 | grand gaube
# Processing Record 31 of Set 10 | san ramon
# Processing Record 32 of Set 10 | do rud
# City not found. Skipping...
# Processing Record 33 of Set 10 | qasigiannguit
# Processing Record 34 of Set 10 | necochea
# Processing Record 35 of Set 10 | niamey
# Processing Record 36 of Set 10 | khuzdar
# Processing Record 37 of Set 10 | bunia
# Processing Record 38 of Set 10 | beira
# Processing Record 39 of Set 10 | corpus christi
# Processing Record 40 of Set 10 | salalah
# Processing Record 41 of Set 10 | otacilio costa
# Processing Record 42 of Set 10 | mao
# Processing Record 43 of Set 10 | grafton
# Processing Record 44 of Set 10 | isiro
# Processing Record 45 of Set 10 | panguna
# Processing Record 46 of Set 10 | ulagan
# Processing Record 47 of Set 10 | meulaboh
# Processing Record 48 of Set 10 | santa rosa
# Processing Record 49 of Set 10 | port macquarie
# Processing Record 50 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 1 of Set 11 | sangin
# Processing Record 2 of Set 11 | padang
# Processing Record 3 of Set 11 | mayo
# Processing Record 4 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 5 of Set 11 | nebolchi
# Processing Record 6 of Set 11 | svetlogorsk
# Processing Record 7 of Set 11 | la rioja
# Processing Record 8 of Set 11 | realeza
# Processing Record 9 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 10 of Set 11 | dayong
# Processing Record 11 of Set 11 | columbus
# Processing Record 12 of Set 11 | vestmannaeyjar
# Processing Record 13 of Set 11 | ferry pass
# Processing Record 14 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 11 | lisakovsk
# Processing Record 16 of Set 11 | quesnel
# Processing Record 17 of Set 11 | yaan
# Processing Record 18 of Set 11 | atherton
# Processing Record 19 of Set 11 | monmouth
# Processing Record 20 of Set 11 | wladyslawowo
# Processing Record 21 of Set 11 | flinders
# Processing Record 22 of Set 11 | takoradi
# Processing Record 23 of Set 11 | naze
# Processing Record 24 of Set 11 | puerto carreno
# Processing Record 25 of Set 11 | ulladulla
# Processing Record 26 of Set 11 | batagay-alyta
# Processing Record 27 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 11 | salta
# Processing Record 29 of Set 11 | santiago del estero
# Processing Record 30 of Set 11 | christchurch
# Processing Record 31 of Set 11 | puerto castilla
# Processing Record 32 of Set 11 | irtyshskiy
# Processing Record 33 of Set 11 | sioux lookout
# Processing Record 34 of Set 11 | udachnyy
# Processing Record 35 of Set 11 | mucurapo
# Processing Record 36 of Set 11 | jalu
# Processing Record 37 of Set 11 | maceio
# Processing Record 38 of Set 11 | guhagar
# Processing Record 39 of Set 11 | srostki
# Processing Record 40 of Set 11 | umm ruwabah
# City not found. Skipping...
# Processing Record 41 of Set 11 | ler
# Processing Record 42 of Set 11 | gayny
# Processing Record 43 of Set 11 | puri
# Processing Record 44 of Set 11 | mujiayingzi
# Processing Record 45 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 46 of Set 11 | praya
# Processing Record 47 of Set 11 | hofn
# Processing Record 48 of Set 11 | altamira
# Processing Record 49 of Set 11 | yei
# Processing Record 50 of Set 11 | barcelona
# Processing Record 1 of Set 12 | robertsonpet
# Processing Record 2 of Set 12 | lom sak
# Processing Record 3 of Set 12 | san quintin
# Processing Record 4 of Set 12 | petatlan
# Processing Record 5 of Set 12 | pak chong
# Processing Record 6 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 12 | guarapari
# Processing Record 8 of Set 12 | bathsheba
# Processing Record 9 of Set 12 | lebork
# Processing Record 10 of Set 12 | taiyuan
# Processing Record 11 of Set 12 | deogarh
# Processing Record 12 of Set 12 | kolyvan
# Processing Record 13 of Set 12 | gornopravdinsk
# Processing Record 14 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 15 of Set 12 | tarko-sale
# Processing Record 16 of Set 12 | fairbanks
# Processing Record 17 of Set 12 | kenora
# Processing Record 18 of Set 12 | egvekinot
# Processing Record 19 of Set 12 | plainview
# Processing Record 20 of Set 12 | flin flon
# Processing Record 21 of Set 12 | chernyshevskiy
# Processing Record 22 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 23 of Set 12 | kameoka
# Processing Record 24 of Set 12 | marmaris
# Processing Record 25 of Set 12 | itaituba
# Processing Record 26 of Set 12 | ponta do sol
# Processing Record 27 of Set 12 | tarakan
# Processing Record 28 of Set 12 | bandarbeyla
# Processing Record 29 of Set 12 | koumac
# Processing Record 30 of Set 12 | teacapan
# Processing Record 31 of Set 12 | kalmunai
# Processing Record 32 of Set 12 | macas
# Processing Record 33 of Set 12 | elizabeth city
# Processing Record 34 of Set 12 | araouane
# Processing Record 35 of Set 12 | andenes
# Processing Record 36 of Set 12 | krasnyy yar
# Processing Record 37 of Set 12 | grindavik
# Processing Record 38 of Set 12 | tomatlan
# Processing Record 39 of Set 12 | nioki
# Processing Record 40 of Set 12 | shitanjing
# Processing Record 41 of Set 12 | lerwick
# Processing Record 42 of Set 12 | dandong
# Processing Record 43 of Set 12 | bayan
# Processing Record 44 of Set 12 | bredy
# Processing Record 45 of Set 12 | baoying
# Processing Record 46 of Set 12 | khandbari
# Processing Record 47 of Set 12 | manutuke
# Processing Record 48 of Set 12 | chumikan
# Processing Record 49 of Set 12 | tam ky
# Processing Record 50 of Set 12 | valparaiso
# Processing Record 1 of Set 13 | birao
# Processing Record 2 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 13 | ahuimanu
# Processing Record 4 of Set 13 | linhares
# Processing Record 5 of Set 13 | otjiwarongo
# Processing Record 6 of Set 13 | alice springs
# Processing Record 7 of Set 13 | santa isabel do rio negro
# Processing Record 8 of Set 13 | lisala
# Processing Record 9 of Set 13 | tongzi
# Processing Record 10 of Set 13 | tukrah
# Processing Record 11 of Set 13 | luba
# Processing Record 12 of Set 13 | den helder
# Processing Record 13 of Set 13 | sungaipenuh
# Processing Record 14 of Set 13 | fort-shevchenko
# Processing Record 15 of Set 13 | naldurg
# Processing Record 16 of Set 13 | ilebo
# Processing Record 17 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 13 | alexandria
# Processing Record 19 of Set 13 | asfi
# Processing Record 20 of Set 13 | sala
# Processing Record 21 of Set 13 | kuala terengganu
# Processing Record 22 of Set 13 | alofi
# Processing Record 23 of Set 13 | masindi
# Processing Record 24 of Set 13 | monrovia
# Processing Record 25 of Set 13 | kaputa
# Processing Record 26 of Set 13 | balgazyn
# Processing Record 27 of Set 13 | khokhryaki
# Processing Record 28 of Set 13 | shimoda
# Processing Record 29 of Set 13 | bilibino
# Processing Record 30 of Set 13 | boddam
# Processing Record 31 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 13 | mareeba
# Processing Record 34 of Set 13 | coahuayana
# Processing Record 35 of Set 13 | tera
# Processing Record 36 of Set 13 | xining
# Processing Record 37 of Set 13 | tambura
# Processing Record 38 of Set 13 | san fernando
# Processing Record 39 of Set 13 | anito
# Processing Record 40 of Set 13 | taksimo
# Processing Record 41 of Set 13 | penzance
# Processing Record 42 of Set 13 | mormugao
# Processing Record 43 of Set 13 | marsabit
# Processing Record 44 of Set 13 | tual
# Processing Record 45 of Set 13 | tynda
# Processing Record 46 of Set 13 | vitim
# Processing Record 47 of Set 13 | pingliang
# Processing Record 48 of Set 13 | sassandra
# Processing Record 49 of Set 13 | likasi
# Processing Record 50 of Set 13 | ancud
# Processing Record 1 of Set 14 | keuruu
# Processing Record 2 of Set 14 | lokosovo
# Processing Record 3 of Set 14 | sabha
# Processing Record 4 of Set 14 | kisangani
# Processing Record 5 of Set 14 | iralaya
# Processing Record 6 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 8 of Set 14 | lumding
# Processing Record 9 of Set 14 | mitchell
# Processing Record 10 of Set 14 | nchelenge
# Processing Record 11 of Set 14 | pacific grove
# Processing Record 12 of Set 14 | bonavista
# Processing Record 13 of Set 14 | aginskoye
# Processing Record 14 of Set 14 | syamzha
# Processing Record 15 of Set 14 | acapulco
# Processing Record 16 of Set 14 | cascais
# Processing Record 17 of Set 14 | indianola
# Processing Record 18 of Set 14 | hornepayne
# Processing Record 19 of Set 14 | pasaco
# Processing Record 20 of Set 14 | gainesville
# Processing Record 21 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 22 of Set 14 | itoman
# Processing Record 23 of Set 14 | general roca
# Processing Record 24 of Set 14 | vallenar
# Processing Record 25 of Set 14 | nancha
# Processing Record 26 of Set 14 | ukiah
# Processing Record 27 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 14 | sechura
# Processing Record 29 of Set 14 | santa fe
# Processing Record 30 of Set 14 | plougastel-daoulas
# Processing Record 31 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 32 of Set 14 | hailey
# Processing Record 33 of Set 14 | atlantic beach
# Processing Record 34 of Set 14 | marienburg
# Processing Record 35 of Set 14 | berea
# Processing Record 36 of Set 14 | maragogi
# Processing Record 37 of Set 14 | novobirilyussy
# Processing Record 38 of Set 14 | berlevag
# Processing Record 39 of Set 14 | caravelas
# Processing Record 40 of Set 14 | tebingtinggi
# Processing Record 41 of Set 14 | san policarpo
# Processing Record 42 of Set 14 | puerto escondido
# Processing Record 43 of Set 14 | roebourne
# Processing Record 44 of Set 14 | sheridan
# Processing Record 45 of Set 14 | taklisah
# Processing Record 46 of Set 14 | la ronge
# Processing Record 47 of Set 14 | samur
# Processing Record 48 of Set 14 | richards bay
# Processing Record 49 of Set 14 | rabo de peixe
# Processing Record 50 of Set 14 | vaitape
# Processing Record 1 of Set 15 | pizarro
# Processing Record 2 of Set 15 | asau
# Processing Record 3 of Set 15 | izhma
# Processing Record 4 of Set 15 | semnan
# Processing Record 5 of Set 15 | achisay
# City not found. Skipping...
# Processing Record 6 of Set 15 | uyuni
# Processing Record 7 of Set 15 | roma
# Processing Record 8 of Set 15 | paamiut
# Processing Record 9 of Set 15 | odweyne
# Processing Record 10 of Set 15 | moranbah
# Processing Record 11 of Set 15 | kiama
# Processing Record 12 of Set 15 | arcachon
# Processing Record 13 of Set 15 | hualmay
# Processing Record 14 of Set 15 | ikom
# Processing Record 15 of Set 15 | qingdao
# Processing Record 16 of Set 15 | banda aceh
# Processing Record 17 of Set 15 | porto santo
# Processing Record 18 of Set 15 | nelson bay
# Processing Record 19 of Set 15 | hami
# Processing Record 20 of Set 15 | achalpur
# Processing Record 21 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 15 | the valley
# Processing Record 24 of Set 15 | notodden
# Processing Record 25 of Set 15 | yarmouth
# Processing Record 26 of Set 15 | campoverde
# Processing Record 27 of Set 15 | iwanai
# Processing Record 28 of Set 15 | qianjiang
# Processing Record 29 of Set 15 | ola
# Processing Record 30 of Set 15 | quimper
# Processing Record 31 of Set 15 | davila
# Processing Record 32 of Set 15 | brewster
# Processing Record 33 of Set 15 | gouyave
# Processing Record 34 of Set 15 | raymondville
# Processing Record 35 of Set 15 | qaqortoq
# Processing Record 36 of Set 15 | gazojak
# Processing Record 37 of Set 15 | tautira
# Processing Record 38 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 39 of Set 15 | iberia
# Processing Record 40 of Set 15 | eskasem
# City not found. Skipping...
# Processing Record 41 of Set 15 | san juan
# Processing Record 42 of Set 15 | zhaotong
# Processing Record 43 of Set 15 | pangkalanbuun
# Processing Record 44 of Set 15 | naugachhia
# Processing Record 45 of Set 15 | trincomalee
# Processing Record 46 of Set 15 | tanete
# Processing Record 47 of Set 15 | beyneu
# Processing Record 48 of Set 15 | safranbolu
# Processing Record 49 of Set 15 | beberibe
# Processing Record 50 of Set 15 | bereda
# Processing Record 1 of Set 16 | mazatlan
# Processing Record 2 of Set 16 | kelso
# Processing Record 3 of Set 16 | moramanga
# Processing Record 4 of Set 16 | ust-maya
# Processing Record 5 of Set 16 | half moon bay
# Processing Record 6 of Set 16 | melbourne
# Processing Record 7 of Set 16 | kwinana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Chokurdakh  70.6333  147.9167      9.21        92          25
# 1        Monte Alegre  -2.0078  -54.0692     71.74        97         100
# 2            Pimentel  -6.8367  -79.9342     66.00        85         100
# 3              Rincon  32.2960  -81.2354     64.40        94           1
# 4  Comodoro Rivadavia -45.8667  -67.5000     68.00        45           0
# 5      Saint-Philippe -21.3585   55.7679     78.80        89          75
# 6               Vaini -21.2000 -175.2000     77.00        88          40
# 7                Sola -13.8833  167.5500     82.99        74          22
# 8              Atuona  -9.8000 -139.0333     80.01        79          27
# 9             Xichang  27.8964  102.2634     82.87        23          81
#
#    Wind Speed Country   Current Weather
# 0        4.65      RU  scattered clouds
# 1        1.32      BR        light rain
# 2        1.99      PE   overcast clouds
# 3        6.91      US         clear sky
# 4       14.97      AR         clear sky
# 5       19.57      RE        light rain
# 6        6.91      TO        light rain
# 7       10.65      VU     moderate rain
# 8       17.31      PF        light rain
# 9       14.07      CN     broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Weather"]

city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Chokurdakh      RU  70.6333  147.9167      9.21        92
# 1          Monte Alegre      BR  -2.0078  -54.0692     71.74        97
# 2              Pimentel      PE  -6.8367  -79.9342     66.00        85
# 3                Rincon      US  32.2960  -81.2354     64.40        94
# 4    Comodoro Rivadavia      AR -45.8667  -67.5000     68.00        45
# ..                  ...     ...      ...       ...       ...       ...
# 691           Moramanga      MG -18.9333   48.2000     64.65        79
# 692            Ust-Maya      RU  60.4167  134.5333     34.83        97
# 693       Half Moon Bay      US  37.4636 -122.4286     53.60        76
# 694           Melbourne      US  28.0836  -80.6081     71.60        83
# 695             Kwinana      AU -32.2500  115.7667     72.00        56
#
#      Cloudiness  Wind Speed   Current Weather
# 0            25        4.65  scattered clouds
# 1           100        1.32        light rain
# 2           100        1.99   overcast clouds
# 3             1        6.91         clear sky
# 4             0       14.97         clear sky
# ..          ...         ...               ...
# 691          95        5.30   overcast clouds
# 692         100        3.96        light rain
# 693           1        7.23         clear sky
# 694          20        3.44        light rain
# 695           4       14.97         clear sky
#
# [696 rows x 9 columns]

# %%
# Export the city_data into a csv file
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City ID")

# %%
# # Retrieve info from the API call
# lat = city_data_df["Lat"]
# lng = city_data_df["Lng"]
# max_temps = city_data_df["Max Temp"]
# humidity = city_data_df["Humidity"]
# cloudiness = city_data_df["cloudiness"]
# wind_speed = city_data_df["Wind Speed"]
# current_weather = city_data_df["Current Weather"]
